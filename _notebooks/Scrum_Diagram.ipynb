# %%
<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1.0">
<title>Scrum Process Diagram</title>
<style>
  body {
    font-family: Arial, sans-serif;
    line-height: 1.6;
    margin: 20px;
  }

  .box {
    border: 1px solid #000;
    padding: 10px;
    margin: 10px;
    background-color: #f0f0f0;
  }

  .arrow {
    text-align: center;
  }
</style>
</head>
<body>

<div class="box">
  <h2>Product Backlog</h2>
  <p>List of desired features, enhancements, and bug fixes for the product. Prioritized by the Product Owner.</p>
</div>

<div class="arrow">
  <span>&darr;</span>
</div>

<div class="box">
  <h2>Sprint Planning</h2>
  <p>Product Owner, Scrum Master, and Development Team meet to plan the next sprint. Select backlog items based on priority and capacity.</p>
</div>

<div class="arrow">
  <span>&darr;</span>
</div>

<div class="box">
  <h2>Sprint Backlog</h2>
  <p>Subset of the Product Backlog items selected for the current sprint. Development Team commits to completing these items.</p>
</div>

<div class="arrow">
  <span>&darr;</span>
</div>

<div class="box">
  <h2>Daily Scrum</h2>
  <p>Development Team meets daily to discuss progress, challenges, and plan for the day.</p>
</div>

<div class="arrow">
  <span>&darr;</span>
</div>

<div class="box">
  <h2>Development</h2>
  <p>Development Team works on selected backlog items to deliver potentially shippable increment.</p>
</div>

<div class="arrow">
  <span>&darr;</span>
</div>

<div class="box">
  <h2>Testing</h2>
  <p>QA team verifies that the increment meets the defined criteria.</p>
</div>

<!-- Add more steps as needed -->

</body>
</html>
# Out:
#   File "/tmp/ipykernel_2853/2509774370.py", line 11
#     margin: 20px;
#              ^
# SyntaxError: invalid decimal literal
